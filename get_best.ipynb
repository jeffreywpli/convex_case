# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import seaborn as sns
import sys
import math
# %matplotlib inline

# %%
def load_data(stat_metrics_file):
    """Loads the data from the given stat_metric and sys_metric files."""
    stat_metrics = pd.read_csv(stat_metrics_file)
    stat_metrics.sort_values(by='Round', inplace=True)
    return stat_metrics

# %%
def get_accuracy_vs_round_number(stat_metrics, refined=True):
    accuracy_key = 'Average Test Acc'
    accuracies = stat_metrics.groupby('Round', as_index=False).mean()
    return accuracies['Round'].as_matrix(), accuracies[accuracy_key].as_matrix()

# %%
def max_from_directory(data_dir, refined=True, column = 'val'):
    files = [f for f in os.listdir(data_dir) if f.endswith('.csv')]
    
    accuracies = []
    rounds = []
    print(str(len(files)) + " files")
    
    if len(files) > 0:
        print("Reached Here")
        print(data_dir)
        for f in files:
            print(f)
            metrics = load_data(os.path.join(data_dir, f))
            round_numbers, acc = get_accuracy_vs_round_number(metrics, refined)

            accuracies.append(acc)
            rounds.append(len(round_numbers))
            print(round_numbers)
            print(str(100 * acc))
            #print(accuracies)
        
        accuracies = 100 * np.array(accuracies)
        if len(files) > 1:
            #accuracies = np.mean(accuracies, axis=0)
            #return accuracies[-1]
            
            last_acc = 0
            for i in range(len(files)):
                last_acc += accuracies[i][-1]
            last_acc /= len(files)    
            
            print(str(last_acc))
            print("")
    
            return last_acc
        print(accuracies[0,-1])
        print("")
        return accuracies[0,-1]

# %%
def print_accs_from_files(data_dir, refined=True):
    files = [f for f in os.listdir(data_dir) if f.endswith('.csv')]
    
    for f in files:
        metrics = load_data(os.path.join(data_dir, f))
        round_numbers, acc = get_accuracy_vs_round_number(metrics, refined)
        
        print(data_dir, f)
        print(100 * np.array(acc))

# %%
DIR = 'results/convex_case/hyper_search/10_shot_5_way/noiseless/'
all_dirs = [x[0] for x in os.walk(DIR) if not x[0] == DIR]
all_accs = [(max_from_directory(path, column='Average Test Acc', refined=False), path) for path in all_dirs]
all_accs = [(acc, path) for acc, path in all_accs if not math.isnan(acc)]
best = max([acc for acc, _ in all_accs])
all_accs_user_level = all_accs
all_accs_user_level
# Out:
# 1 files
# Reached Here
# results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch1.00_grad_10.00000_noise_multiplier_0.5100_meta_step_0.0100_meta_step_final_0.0000_learning_rate_0.0050_dp_sgd_lr_0.0010_train_shots10.00
# seed_8164600.csv
# [    0.   200.   400.   600.   800.  1000.]
# [ 33.72  32.32  34.52  33.86  33.28  34.32]
# 34.32
#
# 1 files
# Reached Here
# results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch1.00_grad_10.00000_noise_multiplier_0.5100_meta_step_0.0100_meta_step_final_0.0000_learning_rate_0.0071_dp_sgd_lr_0.0010_train_shots10.00
# seed_8164600.csv
# [    0.   200.   400.   600.   800.  1000.]
# [ 48.38  49.48  49.48  50.14  50.02  49.52]
# 49.52
#
# 1 files
# Reached Here
# results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch1.00_grad_10.00000_noise_multiplier_0.5100_meta_step_0.0100_meta_step_final_0.0000_learning_rate_0.0100_dp_sgd_lr_0.0010_train_shots10.00
# seed_8164600.csv
# [    0.   200.   400.   600.   800.  1000.]
# [ 20.78  20.48  21.24  20.64  20.76  21.02]
# 21.02
#
# 1 files
# Reached Here
# results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch1.00_grad_10.00000_noise_multiplier_0.5100_meta_step_0.0100_meta_step_final_0.0000_learning_rate_0.1000_dp_sgd_lr_0.0010_train_shots10.00
# seed_8164600.csv
# [    0.   200.   400.   600.   800.  1000.]
# [ 70.14  69.8   70.78  70.84  70.98  70.82]
# 70.82
#
# 1 files
# Reached Here
# results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch1.00_grad_10.00000_noise_multiplier_0.5100_meta_step_0.1000_meta_step_final_0.0000_learning_rate_0.0050_dp_sgd_lr_0.0010_train_shots10.00
# seed_8164600.csv
# [    0.   200.   400.   600.   800.  1000.]
# [ 20.9   20.62  21.7   20.6   21.12  20.66]
# 20.66
#
# 1 files
# Reached Here
# results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch1.00_grad_10.00000_noise_multiplier_0.5100_meta_step_0.1000_meta_step_final_0.0000_learning_rate_0.0141_dp_sgd_lr_0.0010_train_shots10.00
# seed_8164600.csv
# [    0.   200.   400.   600.   800.  1000.]
# [ 50.7   51.66  49.94  50.28  49.68  50.18]
# 50.18
#
# 1 files
# Reached Here
# results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch1.00_grad_10.00000_noise_multiplier_0.5100_meta_step_1.0000_meta_step_final_0.0000_learning_rate_0.0050_dp_sgd_lr_0.0010_train_shots10.00
# seed_8164600.csv
# [    0.   200.   400.   600.   800.  1000.]
# [ 39.9   40.32  41.3   40.14  41.28  42.04]
# 42.04
#
# 1 files
# Reached Here
# results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch1.00_grad_10.00000_noise_multiplier_0.5100_meta_step_1.0000_meta_step_final_0.0000_learning_rate_0.0071_dp_sgd_lr_0.0010_train_shots10.00
# seed_8164600.csv
# [    0.   200.   400.   600.   800.  1000.]
# [ 21.8   22.38  21.98  22.8   22.32  22.78]
# 22.78
#
# 1 files
# Reached Here
# results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch1.00_grad_10.00000_noise_multiplier_0.5100_meta_step_1.0000_meta_step_final_0.0000_learning_rate_0.0100_dp_sgd_lr_0.0010_train_shots10.00
# seed_8164600.csv
# [    0.   200.   400.   600.   800.  1000.]
# [ 20.58  21.48  20.84  20.64  20.96  21.48]
# 21.48
#
# 1 files
# Reached Here
# results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch1.00_grad_10.00000_noise_multiplier_0.5100_meta_step_1.0000_meta_step_final_0.0000_learning_rate_0.0141_dp_sgd_lr_0.0010_train_shots10.00
# seed_8164600.csv
# [    0.   200.   400.   600.   800.  1000.]
# [ 20.9   21.54  20.8   22.    21.52  22.12]
# 22.12
#
# 1 files
# Reached Here
# results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch1.00_grad_10.00000_noise_multiplier_0.5100_meta_step_1.0000_meta_step_final_0.0000_learning_rate_0.1000_dp_sgd_lr_0.0010_train_shots10.00
# seed_8164600.csv
# [    0.   200.   400.   600.   800.  1000.]
# [ 67.26  69.72  69.08  69.4   68.4   70.72]
# 70.72
#
# 1 files
# Reached Here
# results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch1.00_grad_10.00000_noise_multiplier_0.5100_meta_step_1.4142_meta_step_final_0.0000_learning_rate_0.0050_dp_sgd_lr_0.0010_train_shots10.00
# seed_8164600.csv
# [    0.   200.   400.   600.   800.  1000.]
# [ 19.84  20.38  20.34  19.4   19.46  20.  ]
# 20.0
#
# 1 files
# Reached Here
# results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch1.00_grad_10.00000_noise_multiplier_0.5100_meta_step_1.4142_meta_step_final_0.0000_learning_rate_0.0100_dp_sgd_lr_0.0010_train_shots10.00
# seed_8164600.csv
# [    0.   200.   400.   600.   800.  1000.]
# [ 37.36  38.98  39.08  39.82  39.34  39.36]
# 39.36
#
# 1 files
# Reached Here
# results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch1.00_grad_10.00000_noise_multiplier_0.5100_meta_step_1.4142_meta_step_final_0.0000_learning_rate_0.0141_dp_sgd_lr_0.0010_train_shots10.00
# seed_8164600.csv
# [    0.   200.   400.   600.   800.  1000.]
# [ 51.66  54.92  56.08  54.48  55.46  56.16]
# 56.16
#
# 1 files
# Reached Here
# results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch1.00_grad_10.00000_noise_multiplier_0.5100_meta_step_1.4142_meta_step_final_0.0000_learning_rate_0.0500_dp_sgd_lr_0.0010_train_shots10.00
# seed_8164600.csv
# [    0.   200.   400.   600.   800.  1000.]
# [ 23.06  22.74  21.88  20.8   23.88  23.26]
# 23.26
#
# 1 files
# Reached Here
# results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch1.00_grad_10.00000_noise_multiplier_0.5100_meta_step_1.4142_meta_step_final_0.0000_learning_rate_0.1000_dp_sgd_lr_0.0010_train_shots10.00
# seed_8164600.csv
# [    0.   200.   400.   600.   800.  1000.]
# [ 62.7   55.34  56.94  57.02  60.94  59.56]
# 59.56
#
# 1 files
# Reached Here
# results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch1.00_grad_10.00000_noise_multiplier_0.5100_meta_step_2.0000_meta_step_final_0.0000_learning_rate_0.0010_dp_sgd_lr_0.0010_train_shots10.00
# seed_8164600.csv
# [    0.   200.   400.   600.   800.  1000.]
# [ 19.76  19.36  20.58  19.84  20.1   19.78]
# 19.78
#
# 1 files
# Reached Here
# results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch1.00_grad_10.00000_noise_multiplier_0.5100_meta_step_2.0000_meta_step_final_0.0000_learning_rate_0.0050_dp_sgd_lr_0.0010_train_shots10.00
# seed_8164600.csv
# [    0.   200.   400.   600.   800.  1000.]
# [ 33.28  32.48  33.82  33.2   32.96  33.5 ]
# 33.5
#
# 1 files
# Reached Here
# results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch1.00_grad_10.00000_noise_multiplier_0.5100_meta_step_2.0000_meta_step_final_0.0000_learning_rate_0.0071_dp_sgd_lr_0.0010_train_shots10.00
# seed_8164600.csv
# [    0.   200.   400.   600.   800.  1000.]
# [ 21
#
# 1 files
# Reached Here
# results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch5.00_grad_10.00000_noise_multiplier_0.5100_meta_step_1.0000_meta_step_final_0.0000_learning_rate_0.0050_dp_sgd_lr_0.0010_train_shots10.00
# seed_8164600.csv
# [    0.   200.   400.   600.   800.  1000.]
# [ 31.86  33.5   33.92  34.36  33.96  34.32]
# 34.32
#
# 1 files
# Reached Here
# results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch5.00_grad_10.00000_noise_multiplier_0.5100_meta_step_1.0000_meta_step_final_0.0000_learning_rate_0.0100_dp_sgd_lr_0.0010_train_shots10.00
# seed_8164600.csv
# [    0.   200.   400.   600.   800.  1000.]
# [ 21.52  21.96  21.04  20.5   21.46  22.  ]
# 22.0
#
# 1 files
# Reached Here
# results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch5.00_grad_10.00000_noise_multiplier_0.5100_meta_step_1.0000_meta_step_final_0.0000_learning_rate_0.0500_dp_sgd_lr_0.0010_train_shots10.00
# seed_8164600.csv
# [    0.   200.   400.   600.   800.  1000.]
# [ 68.88  68.78  68.82  70.98  70.2   70.  ]
# 70.0
#
# 1 files
# Reached Here
# results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch5.00_grad_10.00000_noise_multiplier_0.5100_meta_step_1.0000_meta_step_final_0.0000_learning_rate_0.1000_dp_sgd_lr_0.0010_train_shots10.00
# seed_8164600.csv
# [    0.   200.   400.   600.   800.  1000.]
# [ 26.08  25.54  25.44  26.7   24.98  24.98]
# 24.98
#
# 1 files
# Reached Here
# results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch5.00_grad_10.00000_noise_multiplier_0.5100_meta_step_1.4142_meta_step_final_0.0000_learning_rate_0.0071_dp_sgd_lr_0.0010_train_shots10.00
# seed_8164600.csv
# [    0.   200.   400.   600.   800.  1000.]
# [ 20.14  19.4   19.74  20.38  19.66  19.94]
# 19.94
#
# 1 files
# Reached Here
# results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch5.00_grad_10.00000_noise_multiplier_0.5100_meta_step_1.4142_meta_step_final_0.0000_learning_rate_0.0100_dp_sgd_lr_0.0010_train_shots10.00
# seed_8164600.csv
# [    0.   200.   400.   600.   800.  1000.]
# [ 33.92  26.78  26.78  28.4   29.12  29.74]
# 29.74
#
# 1 files
# Reached Here
# results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch5.00_grad_10.00000_noise_multiplier_0.5100_meta_step_2.0000_meta_step_final_0.0000_learning_rate_0.0100_dp_sgd_lr_0.0010_train_shots10.00
# seed_8164600.csv
# [    0.   200.   400.   600.   800.  1000.]
# [ 33.5   35.16  34.86  35.2   34.4   35.52]
# 35.52
#
# 1 files
# Reached Here
# results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch5.00_grad_10.00000_noise_multiplier_0.5100_meta_step_2.0000_meta_step_final_0.0000_learning_rate_0.0141_dp_sgd_lr_0.0010_train_shots10.00
# seed_8164600.csv
# [    0.   200.   400.   600.   800.  1000.]
# [ 58.74  38.42  37.4   42.86  44.56  45.94]
# 45.94
#
# 1 files
# Reached Here
# results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch5.00_grad_10.00000_noise_multiplier_0.5100_meta_step_2.0000_meta_step_final_0.0000_learning_rate_0.0500_dp_sgd_lr_0.0010_train_shots10.00
# seed_8164600.csv
# [    0.   200.   400.   600.   800.  1000.]
# [ 26.86  28.02  25.68  26.34  26.52  28.56]
# 28.56
#
# 1 files
# Reached Here
# results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch5.00_grad_10.00000_noise_multiplier_0.5100_meta_step_2.0000_meta_step_final_0.0000_learning_rate_0.1000_dp_sgd_lr_0.0010_train_shots10.00
# seed_8164600.csv
# [    0.   200.   400.   600.   800.  1000.]
# [ 24.92  23.6   23.26  24.46  25.22  25.38]
# 25.38
#
# 1 files
# Reached Here
# results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_5.0_meta_iters_200.0_inner_batch10.00_grad_10.00000_noise_multiplier_0.5100_meta_step_1.0000_meta_step_final_0.0000_learning_rate_0.1000_dp_sgd_lr_0.0010_train_shots10.00
# seed_8164600.csv
# [   0.  200.]
# [ 24.48  25.86]
# 25.86
#
# 1 files
# Reached Here
# results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_5.0_meta_iters_200.0_inner_batch10.00_grad_10.00000_noise_multiplier_0.5100_meta_step_1.0000_meta_step_final_0.0000_learning_rate_0.1000_dp_sgd_lr_0.0010_train_shots45.00
# seed_8164600.csv
# [ 0.]
# [ 24.94]
# 24.94
# [(34.32,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch1.00_grad_10.00000_noise_multiplier_0.5100_meta_step_0.0100_meta_step_final_0.0000_learning_rate_0.0050_dp_sgd_lr_0.0010_train_shots10.00'),
#  (49.519999999999996,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch1.00_grad_10.00000_noise_multiplier_0.5100_meta_step_0.0100_meta_step_final_0.0000_learning_rate_0.0071_dp_sgd_lr_0.0010_train_shots10.00'),
#  (21.02,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch1.00_grad_10.00000_noise_multiplier_0.5100_meta_step_0.0100_meta_step_final_0.0000_learning_rate_0.0100_dp_sgd_lr_0.0010_train_shots10.00'),
#  (70.820000000000007,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch1.00_grad_10.00000_noise_multiplier_0.5100_meta_step_0.0100_meta_step_final_0.0000_learning_rate_0.1000_dp_sgd_lr_0.0010_train_shots10.00'),
#  (20.66,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch1.00_grad_10.00000_noise_multiplier_0.5100_meta_step_0.1000_meta_step_final_0.0000_learning_rate_0.0050_dp_sgd_lr_0.0010_train_shots10.00'),
#  (50.18,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch1.00_grad_10.00000_noise_multiplier_0.5100_meta_step_0.1000_meta_step_final_0.0000_learning_rate_0.0141_dp_sgd_lr_0.0010_train_shots10.00'),
#  (42.039999999999999,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch1.00_grad_10.00000_noise_multiplier_0.5100_meta_step_1.0000_meta_step_final_0.0000_learning_rate_0.0050_dp_sgd_lr_0.0010_train_shots10.00'),
#  (22.780000000000001,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch1.00_grad_10.00000_noise_multiplier_0.5100_meta_step_1.0000_meta_step_final_0.0000_learning_rate_0.0071_dp_sgd_lr_0.0010_train_shots10.00'),
#  (21.48,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch1.00_grad_10.00000_noise_multiplier_0.5100_meta_step_1.0000_meta_step_final_0.0000_learning_rate_0.0100_dp_sgd_lr_0.0010_train_shots10.00'),
#  (22.120000000000001,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch1.00_grad_10.00000_noise_multiplier_0.5100_meta_step_1.0000_meta_step_final_0.0000_learning_rate_0.0141_dp_sgd_lr_0.0010_train_shots10.00'),
#  (70.719999999999999,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch1.00_grad_10.00000_noise_multiplier_0.5100_meta_step_1.0000_meta_step_final_0.0000_learning_rate_0.1000_dp_sgd_lr_0.0010_train_shots10.00'),
#  (20.0,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch1.00_grad_10.00000_noise_multiplier_0.5100_meta_step_1.4142_meta_step_final_0.0000_learning_rate_0.0050_dp_sgd_lr_0.0010_train_shots10.00'),
#  (39.359999999999999,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch1.00_grad_10.00000_noise_multiplier_0.5100_meta_step_1.4142_meta_step_final_0.0000_learning_rate_0.0100_dp_sgd_lr_0.0010_train_shots10.00'),
#  (56.159999999999997,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch1.00_grad_10.00000_noise_multiplier_0.5100_meta_step_1.4142_meta_step_final_0.0000_learning_rate_0.0141_dp_sgd_lr_0.0010_train_shots10.00'),
#  (23.260000000000002,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch1.00_grad_10.00000_noise_multiplier_0.5100_meta_step_1.4142_meta_step_final_0.0000_learning_rate_0.0500_dp_sgd_lr_0.0010_train_shots10.00'),
#  (59.560000000000002,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch1.00_grad_10.00000_noise_multiplier_0.5100_meta_step_1.4142_meta_step_final_0.0000_learning_rate_0.1000_dp_sgd_lr_0.0010_train_shots10.00'),
#  (19.780000000000001,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch1.00_grad_10.00000_noise_multiplier_0.5100_meta_step_2.0000_meta_step_final_0.0000_learning_rate_0.0010_dp_sgd_lr_0.0010_train_shots10.00'),
#  (33.5,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch1.00_grad_10.00000_noise_multiplier_0.5100_meta_step_2.0000_meta_step_final_0.0000_learning_rate_0.0050_dp_sgd_lr_0.0010_train_shots10.00'),
#  (20.68,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch1.00_grad_10.00000_noise_multiplier_0.5100_meta_step_2.0000_meta_step_final_0.0000_learning_rate_0.0071_dp_sgd_lr_0.0010_train_shots10.00'),
#  (22.259999999999998,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch1.00_grad_10.00000_noise_multiplier_0.5100_meta_step_2.0000_meta_step_final_0.0000_learning_rate_0.0100_dp_sgd_lr_0.0010_train_shots10.00'),
#  (36.18,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch1.00_grad_10.00000_noise_multiplier_0.5100_meta_step_2.0000_meta_step_final_0.0000_learning_rate_0.0141_dp_sgd_lr_0.0010_train_shots10.00'),
#  (66.920000000000002,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch1.00_grad_10.00000_noise_multiplier_0.5100_meta_step_2.0000_meta_step_final_0.0000_learning_rate_0.1000_dp_sgd_lr_0.0010_train_shots10.00'),
#  (20.399999999999999,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch10.00_grad_10.00000_noise_multiplier_0.5100_meta_step_0.0100_meta_step_final_0.0000_learning_rate_0.0071_dp_sgd_lr_0.0010_train_shots10.00'),
#  (26.400000000000002,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch10.00_grad_10.00000_noise_multiplier_0.5100_meta_step_0.1000_meta_step_final_0.0000_learning_rate_0.0071_dp_sgd_lr_0.0010_train_shots10.00'),
#  (66.759999999999991,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch10.00_grad_10.00000_noise_multiplier_0.5100_meta_step_0.1000_meta_step_final_0.0000_learning_rate_0.1000_dp_sgd_lr_0.0010_train_shots10.00'),
#  (21.48,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch10.00_grad_10.00000_noise_multiplier_0.5100_meta_step_1.0000_meta_step_final_0.0000_learning_rate_0.0010_dp_sgd_lr_0.0010_train_shots10.00'),
#  (19.66,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch10.00_grad_10.00000_noise_multiplier_0.5100_meta_step_1.0000_meta_step_final_0.0000_learning_rate_0.0050_dp_sgd_lr_0.0010_train_shots10.00'),
#  (20.440000000000001,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch10.00_grad_10.00000_noise_multiplier_0.5100_meta_step_1.0000_meta_step_final_0.0000_learning_rate_0.0071_dp_sgd_lr_0.0010_train_shots10.00'),
#  (31.680000000000003,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch10.00_grad_10.00000_noise_multiplier_0.5100_meta_step_1.0000_meta_step_final_0.0000_learning_rate_0.0100_dp_sgd_lr_0.0010_train_shots10.00'),
#  (21.959999999999997,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch10.00_grad_10.00000_noise_multiplier_0.5100_meta_step_1.0000_meta_step_final_0.0000_learning_rate_0.0141_dp_sgd_lr_0.0010_train_shots10.00'),
#  (25.940000000000001,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch10.00_grad_10.00000_noise_multiplier_0.5100_meta_step_1.0000_meta_step_final_0.0000_learning_rate_0.1000_dp_sgd_lr_0.0010_train_shots10.00'),
#  (27.16,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch10.00_grad_10.00000_noise_multiplier_0.5100_meta_step_1.4142_meta_step_final_0.0000_learning_rate_0.0071_dp_sgd_lr_0.0010_train_shots10.00'),
#  (39.700000000000003,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch10.00_grad_10.00000_noise_multiplier_0.5100_meta_step_1.4142_meta_step_final_0.0000_learning_rate_0.0100_dp_sgd_lr_0.0010_train_shots10.00'),
#  (40.739999999999995,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch10.00_grad_10.00000_noise_multiplier_0.5100_meta_step_1.4142_meta_step_final_0.0000_learning_rate_0.0141_dp_sgd_lr_0.0010_train_shots10.00'),
#  (19.919999999999998,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch10.00_grad_10.00000_noise_multiplier_0.5100_meta_step_1.4142_meta_step_final_0.0000_learning_rate_0.0500_dp_sgd_lr_0.0010_train_shots10.00'),
#  (70.540000000000006,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch10.00_grad_10.00000_noise_multiplier_0.5100_meta_step_1.4142_meta_step_final_0.0000_learning_rate_0.1000_dp_sgd_lr_0.0010_train_shots10.00'),
#  (19.800000000000001,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch10.00_grad_10.00000_noise_multiplier_0.5100_meta_step_2.0000_meta_step_final_0.0000_learning_rate_0.0010_dp_sgd_lr_0.0010_train_shots10.00'),
#  (20.620000000000001,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch10.00_grad_10.00000_noise_multiplier_0.5100_meta_step_2.0000_meta_step_final_0.0000_learning_rate_0.0100_dp_sgd_lr_0.0010_train_shots10.00'),
#  (50.860000000000007,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch10.00_grad_10.00000_noise_multiplier_0.5100_meta_step_2.0000_meta_step_final_0.0000_learning_rate_0.1000_dp_sgd_lr_0.0010_train_shots10.00'),
#  (21.079999999999998,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch15.00_grad_10.00000_noise_multiplier_0.5100_meta_step_0.0100_meta_step_final_0.0000_learning_rate_0.0010_dp_sgd_lr_0.0010_train_shots10.00'),
#  (34.82,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch15.00_grad_10.00000_noise_multiplier_0.5100_meta_step_0.0100_meta_step_final_0.0000_learning_rate_0.0050_dp_sgd_lr_0.0010_train_shots10.00'),
#  (26.079999999999998,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch15.00_grad_10.00000_noise_multiplier_0.5100_meta_step_0.0100_meta_step_final_0.0000_learning_rate_0.0071_dp_sgd_lr_0.0010_train_shots10.00'),
#  (20.979999999999997,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch15.00_grad_10.00000_noise_multiplier_0.5100_meta_step_0.0100_meta_step_final_0.0000_learning_rate_0.1000_dp_sgd_lr_0.0010_train_shots10.00'),
#  (25.259999999999998,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch15.00_grad_10.00000_noise_multiplier_0.5100_meta_step_0.1000_meta_step_final_0.0000_learning_rate_0.0500_dp_sgd_lr_0.0010_train_shots10.00'),
#  (34.560000000000002,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch15.00_grad_10.00000_noise_multiplier_0.5100_meta_step_0.1000_meta_step_final_0.0000_learning_rate_0.1000_dp_sgd_lr_0.0010_train_shots10.00'),
#  (19.52,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch15.00_grad_10.00000_noise_multiplier_0.5100_meta_step_1.0000_meta_step_final_0.0000_learning_rate_0.0010_dp_sgd_lr_0.0010_train_shots10.00'),
#  (31.600000000000001,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch15.00_grad_10.00000_noise_multiplier_0.5100_meta_step_1.0000_meta_step_final_0.0000_learning_rate_0.0050_dp_sgd_lr_0.0010_train_shots10.00'),
#  (21.399999999999999,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch15.00_grad_10.00000_noise_multiplier_0.5100_meta_step_1.0000_meta_step_final_0.0000_learning_rate_0.0071_dp_sgd_lr_0.0010_train_shots10.00'),
#  (33.68,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch15.00_grad_10.00000_noise_multiplier_0.5100_meta_step_1.0000_meta_step_final_0.0000_learning_rate_0.0100_dp_sgd_lr_0.0010_train_shots10.00'),
#  (20.16,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch15.00_grad_10.00000_noise_multiplier_0.5100_meta_step_1.0000_meta_step_final_0.0000_learning_rate_0.0141_dp_sgd_lr_0.0010_train_shots10.00'),
#  (21.460000000000001,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch15.00_grad_10.00000_noise_multiplier_0.5100_meta_step_1.4142_meta_step_final_0.0000_learning_rate_0.0071_dp_sgd_lr_0.0010_train_shots10.00'),
#  (55.059999999999995,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch15.00_grad_10.00000_noise_multiplier_0.5100_meta_step_1.4142_meta_step_final_0.0000_learning_rate_0.1000_dp_sgd_lr_0.0010_train_shots10.00'),
#  (32.940000000000005,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch15.00_grad_10.00000_noise_multiplier_0.5100_meta_step_2.0000_meta_step_final_0.0000_learning_rate_0.0100_dp_sgd_lr_0.0010_train_shots10.00'),
#  (27.52,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch15.00_grad_10.00000_noise_multiplier_0.5100_meta_step_2.0000_meta_step_final_0.0000_learning_rate_0.0141_dp_sgd_lr_0.0010_train_shots10.00'),
#  (48.579999999999998,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch15.00_grad_10.00000_noise_multiplier_0.5100_meta_step_2.0000_meta_step_final_0.0000_learning_rate_0.0500_dp_sgd_lr_0.0010_train_shots10.00'),
#  (28.48,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch15.00_grad_10.00000_noise_multiplier_0.5100_meta_step_2.0000_meta_step_final_0.0000_learning_rate_0.1000_dp_sgd_lr_0.0010_train_shots10.00'),
#  (22.280000000000001,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch5.00_grad_10.00000_noise_multiplier_0.5100_meta_step_0.0100_meta_step_final_0.0000_learning_rate_0.0100_dp_sgd_lr_0.0010_train_shots10.00'),
#  (20.940000000000001,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch5.00_grad_10.00000_noise_multiplier_0.5100_meta_step_0.0100_meta_step_final_0.0000_learning_rate_0.0141_dp_sgd_lr_0.0010_train_shots10.00'),
#  (20.119999999999997,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch5.00_grad_10.00000_noise_multiplier_0.5100_meta_step_0.0100_meta_step_final_0.0000_learning_rate_0.0500_dp_sgd_lr_0.0010_train_shots10.00'),
#  (59.340000000000003,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch5.00_grad_10.00000_noise_multiplier_0.5100_meta_step_0.0100_meta_step_final_0.0000_learning_rate_0.1000_dp_sgd_lr_0.0010_train_shots10.00'),
#  (26.419999999999998,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch5.00_grad_10.00000_noise_multiplier_0.5100_meta_step_0.1000_meta_step_final_0.0000_learning_rate_0.0071_dp_sgd_lr_0.0010_train_shots10.00'),
#  (35.640000000000001,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch5.00_grad_10.00000_noise_multiplier_0.5100_meta_step_0.1000_meta_step_final_0.0000_learning_rate_0.0100_dp_sgd_lr_0.0010_train_shots10.00'),
#  (20.5,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch5.00_grad_10.00000_noise_multiplier_0.5100_meta_step_0.1000_meta_step_final_0.0000_learning_rate_0.0141_dp_sgd_lr_0.0010_train_shots10.00'),
#  (67.359999999999999,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch5.00_grad_10.00000_noise_multiplier_0.5100_meta_step_0.1000_meta_step_final_0.0000_learning_rate_0.0500_dp_sgd_lr_0.0010_train_shots10.00'),
#  (69.060000000000002,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch5.00_grad_10.00000_noise_multiplier_0.5100_meta_step_0.1000_meta_step_final_0.0000_learning_rate_0.1000_dp_sgd_lr_0.0010_train_shots10.00'),
#  (21.579999999999998,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch5.00_grad_10.00000_noise_multiplier_0.5100_meta_step_1.0000_meta_step_final_0.0000_learning_rate_0.0010_dp_sgd_lr_0.0010_train_shots10.00'),
#  (34.32,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch5.00_grad_10.00000_noise_multiplier_0.5100_meta_step_1.0000_meta_step_final_0.0000_learning_rate_0.0050_dp_sgd_lr_0.0010_train_shots10.00'),
#  (22.0,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch5.00_grad_10.00000_noise_multiplier_0.5100_meta_step_1.0000_meta_step_final_0.0000_learning_rate_0.0100_dp_sgd_lr_0.0010_train_shots10.00'),
#  (70.0,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch5.00_grad_10.00000_noise_multiplier_0.5100_meta_step_1.0000_meta_step_final_0.0000_learning_rate_0.0500_dp_sgd_lr_0.0010_train_shots10.00'),
#  (24.98,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch5.00_grad_10.00000_noise_multiplier_0.5100_meta_step_1.0000_meta_step_final_0.0000_learning_rate_0.1000_dp_sgd_lr_0.0010_train_shots10.00'),
#  (19.939999999999998,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch5.00_grad_10.00000_noise_multiplier_0.5100_meta_step_1.4142_meta_step_final_0.0000_learning_rate_0.0071_dp_sgd_lr_0.0010_train_shots10.00'),
#  (29.739999999999998,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch5.00_grad_10.00000_noise_multiplier_0.5100_meta_step_1.4142_meta_step_final_0.0000_learning_rate_0.0100_dp_sgd_lr_0.0010_train_shots10.00'),
#  (35.520000000000003,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch5.00_grad_10.00000_noise_multiplier_0.5100_meta_step_2.0000_meta_step_final_0.0000_learning_rate_0.0100_dp_sgd_lr_0.0010_train_shots10.00'),
#  (45.939999999999998,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch5.00_grad_10.00000_noise_multiplier_0.5100_meta_step_2.0000_meta_step_final_0.0000_learning_rate_0.0141_dp_sgd_lr_0.0010_train_shots10.00'),
#  (28.560000000000002,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch5.00_grad_10.00000_noise_multiplier_0.5100_meta_step_2.0000_meta_step_final_0.0000_learning_rate_0.0500_dp_sgd_lr_0.0010_train_shots10.00'),
#  (25.380000000000003,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch5.00_grad_10.00000_noise_multiplier_0.5100_meta_step_2.0000_meta_step_final_0.0000_learning_rate_0.1000_dp_sgd_lr_0.0010_train_shots10.00'),
#  (25.859999999999999,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_5.0_meta_iters_200.0_inner_batch10.00_grad_10.00000_noise_multiplier_0.5100_meta_step_1.0000_meta_step_final_0.0000_learning_rate_0.1000_dp_sgd_lr_0.0010_train_shots10.00'),
#  (24.940000000000001,
#   'results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_5.0_meta_iters_200.0_inner_batch10.00_grad_10.00000_noise_multiplier_0.5100_meta_step_1.0000_meta_step_final_0.0000_learning_rate_0.1000_dp_sgd_lr_0.0010_train_shots45.00')]

# %%
best_path = [path for acc, path in all_accs if acc == best]
print(best, best_path)
for p in best_path:
    print_accs_from_files(p, refined=False)
# Out:
# 70.82 ['results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch1.00_grad_10.00000_noise_multiplier_0.5100_meta_step_0.0100_meta_step_final_0.0000_learning_rate_0.1000_dp_sgd_lr_0.0010_train_shots10.00']
# results/convex_case/hyper_search/10_shot_5_way/noiseless/meta_batches_1.0_meta_iters_1000.0_inner_batch1.00_grad_10.00000_noise_multiplier_0.5100_meta_step_0.0100_meta_step_final_0.0000_learning_rate_0.1000_dp_sgd_lr_0.0010_train_shots10.00 seed_8164600.csv
# [ 70.14  69.8   70.78  70.84  70.98  70.82]
